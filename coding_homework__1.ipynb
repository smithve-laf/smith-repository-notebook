# %% [markdown]
# <a href="https://colab.research.google.com/github/smithve-laf/smith-repository-notebook/blob/main/coding_homework__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Tori Smith
# #####*Intro to Neural Data Analysis*
# #####**2/6/2026**

# %%
#running this code to import pandas, numpy, and pyplot?

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
#storing v_rest_sst.csv and v_rest_pvalb.csv datasets as strings
url1 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_sst.csv'
url2 = 'https://raw.githubusercontent.com/hallockh/neur_265_spring2026/refs/heads/main/data/v_rest_pvalb.csv'

pandas_data1 = pd.read_csv(url1)
pandas_data2 = pd.read_csv(url2)

# %%
#converting pandas_data1 into a list variable called data1, doing the same for pandas_data2

data1 = pandas_data1.values.tolist()
data2 = pandas_data2.values.tolist()

# %%
#fixing the brackets, flattening data1 and data2
data1 = np.squeeze(data1)
data2 = np.squeeze(data2)

# %%
#printing the length of data1
length1 = len(data1)
print(length1)
# Out:
# 499

# %%
#printing the 3rd, 4th, 5th, and 6th elements of data2
print(data2[2:7])
# Out:
# [-72.36807022 -63.09300825 -75.5469301  -66.51929994 -71.50055833]

# %%
#printing second-to-last and last elements of data1
print(data1[-2:])
# Out:
# [-65.59535842 -75.10678711]

# %%
#type of data2
data2?
#type: ndarray - an array object (fixed-size items)

# %%
#using matplotlib to make a histogram of data1
plt.hist(data1)
# Out:
# (array([  3.,   4.,  23.,  77., 125., 107.,  90.,  42.,  21.,   7.]),
#  array([-88.07835484, -84.19758717, -80.31681949, -76.43605182,
#         -72.55528415, -68.67451648, -64.7937488 , -60.91298113,
#         -57.03221346, -53.15144578, -49.27067811]),
#  <BarContainer object of 10 artists>)

# %%
#re-making histogram for data 1 and labeling axis

#I was having problems getting the data to show on the graph because it was scaled 0 to 1.
#because of this I put it into bins and rescaled them on the same scale like we did in class.
plt.hist(data1, bins=10)

plt.xlim(-90, -45)
plt.ylim(0, 150)

#labels for data1
plt.xlabel('Resting Membrane Potential (mV)')
plt.ylabel('Frequency')
plt.title('SST')
# Out:
# Text(0.5, 1.0, 'SST')

# %%
#making a histogram for data2
plt.hist(data2)
# Out:
# (array([  7.,  28., 117., 148.,  96.,  66.,  26.,   6.,   4.,   1.]),
#  array([-85.27155304, -81.26054661, -77.24954018, -73.23853375,
#         -69.22752732, -65.2165209 , -61.20551447, -57.19450804,
#         -53.18350161, -49.17249518, -45.16148875]),
#  <BarContainer object of 10 artists>)

# %%
#re-making histogram for data2 and labeling axis
plt.hist(data2, bins=10)

plt.xlim(-90, -45)
plt.ylim(0, 150)

#labels for data2
plt.xlabel('Resting Membrane Potential (mV)')
plt.ylabel('Frequency')
plt.title('PVALB')
# Out:
# Text(0.5, 1.0, 'PVALB')

# %% [markdown]
# #####Both of these graphs look very similar, but the pvalb data seems to have a higher ??? (wait what does this have to do with resting membrane potential? is this not ISI?

# %%
#creating data3 variable.
data3 = data1 + data2

# %%
#last element of data2 by indexing data3
print(data2[-1])
print(data3[-1])
#when i index data3 it gives me -129. something something which is not the last element of data2? dont know what i did wrong here.
#did i not combine data sets in data3 correctly? i dont know what i did wrong.

data3 = np.concatenate((data1, data2))
print(data3[-1])

#okay i realized that i didnt do the concatenation correctly.
#but i think the data3 = data1 + data2 should have worked also??
# Out:
# -54.08427915
# -129.19106626
# -54.08427915

# %%
#final answer for step 16
print(data3[-1])
# Out:
# -54.08427915
